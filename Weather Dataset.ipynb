# %% [markdown]
# # Exploratory Data Analysis on Weather/Rainfall dataset

# %%
#Importing image
from IPython import display
display.Image("D:\\Maiya.png",width=1000)

# %%
#Import the library
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Read the dataset from local directory
df=pd.read_csv('C:\\Users\\Dell\\Downloads\\weatherAUS.csv')

# %%
#Displaying the imported dataset
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
#Displaying attributes name
print("There are 23 attributes present, that are as follows--->",list(df))
# Out:
# There are 23 attributes present, that are as follows---> ['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow']

# %%
#Displaying number of attributes and tuples
row, col=df.shape
print('Total number of tuples:', row)
print('Total number of attributes:', col)
# Out:
# Total number of tuples: 145460
# Total number of attributes: 23

# %% [markdown]
# # Checking for Datatypes, Unique values & Missing values

# %%
#Checking data types
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
#Checking unique values
print ("Unique values are:\n",df.nunique())
# Out:
# Unique values are:
#  Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          681
# Evaporation       358
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           441
# Temp3pm           502
# RainToday           2
# RainTomorrow        2
# dtype: int64

# %%
#To check any duplicated values to acheive better analysis by removing any duplicated values that are present
df.duplicated().sum()
# Out:
# 0

# %%
#checking numbers of tuples data Citywise 
City_summary=df['Location'].value_counts().reset_index()
City_summary.columns=(['City','Counts'])
City_summary
# Out:
#                 City  Counts
# 0           Canberra    3436
# 1             Sydney    3344
# 2             Darwin    3193
# 3          Melbourne    3193
# 4           Brisbane    3193
# 5           Adelaide    3193
# 6              Perth    3193
# 7             Hobart    3193
# 8             Albany    3040
# 9       MountGambier    3040
# 10          Ballarat    3040
# 11        Townsville    3040
# 12         GoldCoast    3040
# 13            Cairns    3040
# 14        Launceston    3040
# 15      AliceSprings    3040
# 16           Bendigo    3040
# 17            Albury    3040
# 18       MountGinini    3040
# 19        Wollongong    3040
# 20         Newcastle    3039
# 21       Tuggeranong    3039
# 22           Penrith    3039
# 23           Woomera    3009
# 24         Nuriootpa    3009
# 25             Cobar    3009
# 26      CoffsHarbour    3009
# 27             Moree    3009
# 28              Sale    3009
# 29      PerthAirport    3009
# 30        PearceRAAF    3009
# ...

# %%
#checking missing values
missing_values=df.isnull().sum()
missing_values
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#sum of missing values
Sum_missing_values=missing_values.sum()

# %%
#sum of total values
total_values=np.product(df.shape)

# %%
#checking missing values percentage
percent_missing = (Sum_missing_values/total_values) * 100
print(percent_missing)
# Out:
# 10.259745694319072

# %% [markdown]
# There are 10.25% of missing values present in a dataset

# %%
#Plotting histogram for checking the spread of the dataset
df.hist(figsize=(16,8),xlabelsize=7)
plt.show()

# %%
#Plotting boxplot for checking the spread of the dataset
df.boxplot(figsize=(16,8))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Filling missing values with Mean, Median, and Mode

# %%
# replace missing values with the median
#choosing median because the dates avaliable in dataset are in continous form and as per the observation N/A values are not in continous in our data, so taking average of previous date value and next date value  
def impute_median(miss):
    return miss.fillna(miss.median())

# %%
#utilizing impute_median function to transfrom and fill the null values in Min and Max temperature 
df['MinTemp']=df['MinTemp'].transform(impute_median)
df['MaxTemp']=df['MaxTemp'].transform(impute_median)

# %%
# replace missing values with the mean
df['Rainfall'].fillna(df['Rainfall'].mean(), inplace=True)
df['Evaporation'].fillna(df['Evaporation'].mean(), inplace=True)
df['Sunshine'].fillna(df['Sunshine'].mean(), inplace=True)
df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean(), inplace=True)
df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean(), inplace=True)
df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean(), inplace=True)
df['Humidity9am'].fillna(df['Humidity9am'].mean(), inplace=True)
df['Humidity3pm'].fillna(df['Humidity3pm'].mean(), inplace=True)
df['Cloud9am'].fillna(df['Cloud9am'].mean(), inplace=True)
df['Cloud3pm'].fillna(df['Cloud3pm'].mean(), inplace=True)
df['Temp9am'].fillna(df['Temp9am'].mean(), inplace=True)
df['Temp3pm'].fillna(df['Temp3pm'].mean(), inplace=True)
df['Pressure9am'].fillna(df['Pressure9am'].mean(), inplace=True)
df['Pressure3pm'].fillna(df['Pressure3pm'].mean(), inplace=True)

# %%
# replace missing values with the mode
df['WindGustDir'].fillna(df['WindGustDir'].mode()[0], inplace=True)
df['WindDir9am'].fillna(df['WindDir9am'].mode()[0], inplace=True)
df['WindDir3pm'].fillna(df['WindDir3pm'].mode()[0], inplace=True)
df['RainToday'].fillna(df['RainToday'].mode()[0], inplace=True)
df['RainTomorrow'].fillna(df['RainTomorrow'].mode()[0], inplace=True)

# %%
#check if the missing values are filled
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# Now, the dataset are completely filled and no missing value is observed, we can start analysing data one by one

# %%
#convert object type of date to datetime format
df["Date"]=pd.to_datetime(df['Date'])
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Univariate Analysis for numerical values

# %%
#Plotting histogram for checking the spread of the dataset after missing values handled
df.hist(figsize=(20,10),xlabelsize=7)
plt.show()

# %% [markdown]
#     We can observe that the graph after handling missing values are giving the right spread of the dataset.

# %%
#Plotting boxplot for checking the spread of the dataset after missing values handled
df.boxplot(figsize=(16,8))
plt.xticks(rotation=90)
plt.title('Measure of numerical variables',fontsize=25)
plt.xlabel('Meteorological data',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# Graph is showing the presence of limited number of outliers.

# %%
# plt.figure(1)
plt.subplot(121)
sns.distplot(df['MinTemp'],color='y');

plt.subplot(122)
df['MinTemp'].plot.box(figsize=(16,5))

plt.show()

df['MinTemp'].mean()
# Out:
# 12.192053485494126

# %% [markdown]
# The Majority amount of days had a Minimum temperature of 12

# %%
# plt.figure(2)
plt.subplot(121)
sns.distplot(df['MaxTemp'],color='g');

plt.subplot(122)
df['MaxTemp'].plot.box(figsize=(16,5))

plt.show()

df['MaxTemp'].mean()
# Out:
# 23.21596177643397

# %% [markdown]
# The majority amount of days had a Maximum temperature of 23

# %%
# plt.figure()
plt.subplot(121)
sns.distplot(df['Rainfall'])

plt.subplot(122)
df['MaxTemp'].plot.box(figsize=(16,5))

plt.show()

df['Rainfall'].mean()
# Out:
# 2.3609181499170364

# %% [markdown]
# The average rainfall depth was 2

# %% [markdown]
# # Univariate Analysis for categorical values

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(df['WindGustDir'].value_counts())
sns.rugplot(df['WindGustDir'].value_counts())
plt.title('Measure of wind gust direction',fontsize=25)
plt.xlabel('WindGustDir',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# The graph of Measure of wind gust direction is showing the days having more direction flowing from west side

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['WindGustDir'])
plt.title('Measure of wind direction at 9am',fontsize=25)
plt.xlabel('WindGustDir',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# The graph of Measure of wind direction at 9am is showing the days having more direction flowing from North side at 9am

# %%
df['WindDir3pm'].value_counts().plot.bar(figsize=(12,8),color='y')
plt.title('Measure of wind direction at 3pm',fontsize=25)
plt.xlabel('WindGustDir',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# The graph of Measure of wind direction at 3pm is showing the days having more direction flowing from southeast side at 3pm

# %%
df['RainToday'].value_counts().plot.bar(figsize=(12,8),color='r')
plt.title('Total number of days having possibility of rain on that day',fontsize=20)
plt.xlabel('Raining status',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# There were lesser period of days having rain occuring on that day

# %%
df['RainTomorrow'].value_counts().plot.bar(figsize=(12,8))
plt.title('Total number of days having possibility of rain on next day',fontsize=20)
plt.xlabel('Raining status',fontsize=15)
plt.ylabel('counts',fontsize=15)
plt.show()

# %% [markdown]
# There were lesser period of days having rain occuring on next day

# %% [markdown]
# # Bivariate Analysis

# %%
df
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6     5.468232  7.611178
# 1      2008-12-02   Albury      7.4     25.1       0.0     5.468232  7.611178
# 2      2008-12-03   Albury     12.9     25.7       0.0     5.468232  7.611178
# 3      2008-12-04   Albury      9.2     28.0       0.0     5.468232  7.611178
# 4      2008-12-05   Albury     17.5     32.3       1.0     5.468232  7.611178
# ...           ...      ...      ...      ...       ...          ...       ...
# 145455 2017-06-21    Uluru      2.8     23.4       0.0     5.468232  7.611178
# 145456 2017-06-22    Uluru      3.6     25.3       0.0     5.468232  7.611178
# 145457 2017-06-23    Uluru      5.4     26.9       0.0     5.468232  7.611178
# 145458 2017-06-24    Uluru      7.8     27.0       0.0     5.468232  7.611178
# 145459 2017-06-25    Uluru     14.9     22.6       0.0     5.468232  7.611178
#
# ...

# %%
#figure1
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.boxplot(data=df, x="RainToday", y="MaxTemp",color='plum')
plt.show()

# %%
#figure2
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.violinplot(data=df, y="MaxTemp", x="RainTomorrow",color='oldlace')
plt.show()

# %% [markdown]
# By figure 1 and figure 2 we can tell that if the temperature is maximum the possibility of rain would be less

# %%
#figure1
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.stripplot(data=df, y="MinTemp", x="RainToday",jitter=True)
plt.show()

# %%
#figure2
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.barplot(data=df, y="MinTemp", x="RainTomorrow",color='darkcyan')
plt.show()

# %% [markdown]
# By figure 1 and figure 2 we can tell that if the temperature is minimum the possibility of rain would be more

# %% [markdown]
# # Citywise maximum, minimum, and Rainfall temperature

# %%
#Calculate total salary based on Job Title
Location_temp=df.groupby(['Location'])['MinTemp','MaxTemp','Rainfall'].mean()
Location_temp
# Out:
#                     MinTemp    MaxTemp  Rainfall
# Location
# Adelaide          12.579142  22.898653  1.591736
# Albany            12.928783  20.115921  2.264626
# Albury             9.539539  22.640724  1.918377
# AliceSprings      13.141908  29.244046  0.886739
# BadgerysCreek     11.142107  24.017414  2.197619
# Ballarat           7.369474  18.288684  1.742477
# Bendigo            8.595954  21.623355  1.620844
# Brisbane          16.411337  26.431506  3.137034
# Cairns            21.217434  29.558849  5.684200
# Canberra           6.830908  20.978056  1.744964
# Cobar             13.147159  25.866833  1.135919
# CoffsHarbour      14.424958  23.956763  5.011237
# Dartmoor           8.697541  19.758225  2.151340
# Darwin            23.205794  32.537864  5.092452
# GoldCoast         17.357993  25.759770  3.741597
# Hobart             9.078578  17.867210  1.603008
# Katherine         20.287959  34.622750  3.191506
# Launceston         7.844408  18.962105  2.013365
# ...

# %%
sns.clustermap(Location_temp)

# %% [markdown]
# Data has been cleaned and can be taken for further analysis,
# No skewness for the required data for analysis found,
# No major outlier for the required data for analysis found
